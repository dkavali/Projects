# %% [markdown]
# # Mid Term project - 'Netflix dataset Analysis'
#
# ##### Data Set abstract :
# This Netflix dataset consists of 7787 rows and 12 columns. This dataset contains information related to the type of the show, Cast, Genre, Country of release, Date of release, rating, Duration of the show etc. With this data, I've represented type of shows or movies, Top 20 Countries which contribute the most, Top 20 Actors, Top 20 Genres, Top 20 Ratings, Top 20 Directors on netflix, Frequency between type and rating, Releases of Movies/TV Shows across the years.
#
# ##### Link :
#  https://data.world/drbuck/testdfsdfsd/workspace/file?filename=NetFlix.csv

# %%
# importing required packages
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt  
# %matplotlib inline
import seaborn as sns

# %%
#importing data
data = pd.read_csv("C://Users//diksh//OneDrive//Desktop//DATA SCIENCE//DATA-601//data601-2//Midterm//NetFlix.csv")

# %%
data
# Out:
#      show_id     type                                      title  \
# 0         s1  TV Show                                         3%
# 1        s10    Movie                                       1920
# 2       s100    Movie                                 3 Heroines
# 3      s1000    Movie  Blue Mountain State: The Rise of Thadland
# 4      s1001  TV Show                             Blue Planet II
# ...      ...      ...                                        ...
# 7782    s995  TV Show                                 Blown Away
# 7783    s996  TV Show                              Blue Exorcist
# 7784    s997    Movie                  Blue Is the Warmest Color
# 7785    s998    Movie                               Blue Jasmine
# 7786    s999    Movie                                   Blue Jay
#
#                  director                                               cast  \
# 0                     NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# ##  1. Data Exploration

# %%
data.head()
# Out:
#   show_id     type                                      title        director  \
# 0      s1  TV Show                                         3%             NaN
# 1     s10    Movie                                       1920    Vikram Bhatt
# 2    s100    Movie                                 3 Heroines  Iman Brotoseno
# 3   s1000    Movie  Blue Mountain State: The Rise of Thadland    Lev L. Spiro
# 4   s1001  TV Show                             Blue Planet II             NaN
#
#                                                 cast         country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...          Brazil
# 1  Rajneesh Duggal, Adah Sharma, Indraneil Sengup...           India
# 2  Reza Rahadian, Bunga Citra Lestari, Tara Basro...       Indonesia
# 3  Alan Ritchson, Darin Brooks, James Cade, Rob R...   United States
# 4                                 David Attenborough  United Kingdom
#
#   date_added  release_year rating  duration  \
# ...

# %%
data.shape
# Out:
# (7787, 12)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
 # describe data
data.describe()
# Out:
#        release_year     duration
# count   7787.000000  7787.000000
# mean    2013.932580    69.122769
# std        8.757395    50.950743
# min     1925.000000     1.000000
# 25%     2013.000000     2.000000
# 50%     2017.000000    88.000000
# 75%     2018.000000   106.000000
# max     2021.000000   312.000000

# %%
#column types Info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7787 entries, 0 to 7786
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       7787 non-null   object
#  1   type          7787 non-null   object
#  2   title         7787 non-null   object
#  3   director      5398 non-null   object
#  4   cast          7069 non-null   object
#  5   country       7280 non-null   object
#  6   date_added    7777 non-null   object
#  7   release_year  7787 non-null   int64
#  8   rating        7780 non-null   object
#  9   duration      7787 non-null   int64
#  10  genres        7787 non-null   object
#  11  description   7787 non-null   object
# dtypes: int64(2), object(10)
# memory usage: 730.2+ KB

# %%
 #count of rows
data.count()
# Out:
# show_id         7787
# type            7787
# title           7787
# director        5398
# cast            7069
# country         7280
# date_added      7777
# release_year    7787
# rating          7780
# duration        7787
# genres          7787
# description     7787
# dtype: int64

# %%
# to find the Unique values in the data set
data.nunique()
# Out:
# show_id         7787
# type               2
# title           7787
# director        4049
# cast            6831
# country          681
# date_added      1565
# release_year      73
# rating            14
# duration         206
# genres           492
# description     7769
# dtype: int64

# %%
# total null values in the data set
data.isnull().sum().sum()
# Out:
# 3631

# %% [markdown]
# - we have a total of 3631 Null values in the dataset

# %%
 #Number of Null values column wise
data.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2389
# cast             718
# country          507
# date_added        10
# release_year       0
# rating             7
# duration           0
# genres             0
# description        0
# dtype: int64

# %% [markdown]
# ## 2. Data Preprocessing

# %% [markdown]
# ### Cleaning Data :
#
# *To handle all null values, we can use imputation method for missing value by filling it in using fillna function and then drop rows containing missing values.*
#
# Director - 2389 values are blank.
# Cast - 718 values are blank.
# country - 507 values are blank.
#
# - We can fill the missing values using fillna function for Director, Cast and Country.
#
# date_added - 10 values are blank
# rating - 7 rows are blank.
#
# - We can drop the missing rows of date_added and rating as it is not going to impact our analysis.

# %%
# filling the missing values with No Director, No Cast, Country Unavailable for Director, Cast and Country columns respectively
data.director.fillna("No Director", inplace=True)
data.cast.fillna("No Cast", inplace=True)
data.country.fillna("Country Unavailable", inplace=True)

# Dropping the rows of date_added and rating.
data.dropna(subset=["date_added", "rating"], inplace=True)

# %%
 #Number of NA values
data.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# cast            0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# genres          0
# description     0
# dtype: int64

# %% [markdown]
# - There are no Null values in the dataset now.

# %%
 #to find duplicate rows
data.duplicated().sum()
# Out:
# 0

# %%
data['rating'].nunique()
# Out:
# 14

# %%
data.count()
# Out:
# show_id         7770
# type            7770
# title           7770
# director        7770
# cast            7770
# country         7770
# date_added      7770
# release_year    7770
# rating          7770
# duration        7770
# genres          7770
# description     7770
# dtype: int64

# %% [markdown]
# - We have All columns with same number of rows.

# %% [markdown]
# ## 3. Data Visualisation

# %% [markdown]
# ## 3.1 Types of Shows Telecasted on Netflix

# %%
data['type'].nunique()
# Out:
# 2

# %%
data['type'].value_counts()
# Out:
# Movie      5372
# TV Show    2398
# Name: type, dtype: int64

# %%
# Bar graph for Type of Show released - Movie or TV show

data['type'].value_counts().plot( kind = 'bar')
plt.ylabel('Count')
plt.xlabel('Type')
plt.title('Netflix series categorised based on Type')
plt.show()

# %% [markdown]
#  - We see there are more movies released in Netflix when compared to TV shows.

# %% [markdown]
# ## 3.2 Top 20 years which has more releases

# %%
data['release_year'].value_counts().head(20).plot(kind = 'bar',figsize=(15,7))
plt.xlabel('Year')
plt.ylabel('Count')
plt.title('Years with highest releases')
plt.show()

# %% [markdown]
# ## 3.3 Rating of Netflix Shows/Movies

# %%
data['rating'].value_counts().plot( kind = 'bar',figsize=(15,7))
plt.ylabel('Rating')
plt.xlabel(' Count')
plt.title('Netflix series categorised based on Rating')
#plt.xlim(0, 3000)
plt.show()

# %%
df_rating = data['rating'].value_counts()
labels = data['rating'].unique()
#pie graph representation
plt.figure(figsize=(10,10))
plt.pie(df_rating, labels = labels, autopct='%1.1f%%', textprops = {"fontsize":10})
plt.show()

# %% [markdown]
# ### *Description of Movie/TV Show Ratings:*
#
# - TV-Y : Intended for children ages 2 to 6 and is not designed or expected to frighten.
# - TV-Y7: Intended for children ages 7 and older. Best suited for children who know the difference between real life and make-believe. Contains mild fantasy or comedic violence. Some content could frighten younger children (under age 7).
# - TV-Y7 FV: Intended for older children. Contains fantasy violence more combative than TVY7 programs.
# - TV-G: Intended for all ages. Contains little or no violence, no strong language and little or no sexual dialogue or situations.
# - TV-PG: Intended for younger children in the company of an adult. Possibly contains some suggestive dialogue, infrequent coarse language, some sexual situations or some moderate violence.
# - TV-14: Intended for children ages 14 and older in the company of an adult. Possibly contains intensely suggestive dialogue, strong coarse language, intense sexual situations or intense violence.
# - TV-MA: Intended for adults and may be unsuitable for children under 17. Possibly contains crude indecent language, explicit sexual activity or graphic violence.
# - G: This program is designed to be appropriate for all ages. This rating indicates a film contains nothing that would offend parents for viewing by children.
# - PG: Parents are urged to give parental guidance. This film may contain some material parents might not like for their young children.
# - PG-13: Some material may not be suited for children under age 13. May contain violence, nudity, sensuality, language, adult activities or other elements beyond a PG rating, but doesn’t reach the restricted R category.
# - R: This rating is for films specifically designed to be viewed by adults and therefore may be unsuitable for children under 17.
# - NC-17: This rating is applied to films the MPAA believes most parents will consider inappropriate for children 17 and under. It indicates only that adult content is more intense than in an R rated movie.

# %% [markdown]
# ## 3.4 Top 20 Countries contributing more on Netflix

# %%
countries = data.set_index('title').country.str.split(', ', expand=True).stack().reset_index(level=1, drop=True);
countries = countries[countries != 'Country Unavailable']

# %%
plt.figure(figsize=(15,7))
top20_co = countries.value_counts().index[:20]
sns.countplot(y = countries, order = top20_co)
plt.title('Top 20 Countries Contributing on Netflix')
plt.xlabel('Titles')
plt.ylabel('Country')
plt.show()

# %% [markdown]
# ## 3.5 Top 20 Actors on Netflix

# %%
actors = data.set_index('title').cast.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
actors = actors[actors != 'No Cast']
plt.figure(figsize=(15,7))
plt.title('Top 20 Actors Based on Netflix')
top20_ca = actors.value_counts().index[:20]
sns.countplot(y = actors, order = top20_ca)
plt.show()

# %% [markdown]
# ## 3.6 Top 10 Actors of TV Shows on Netflix

# %%
data_movies = data[data.type.str.contains("Movie")]
data_shows = data[data.type.str.contains("TV Show")]
data.year_added = pd.DatetimeIndex(data.date_added).year
data_movies.year_added = pd.DatetimeIndex(data_movies.date_added).year
data_shows.year_added = pd.DatetimeIndex(data_shows.date_added).year
# Out:
# <ipython-input-37-5239cfe103ab>:3: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data.year_added = pd.DatetimeIndex(data.date_added).year
# <ipython-input-37-5239cfe103ab>:4: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data_movies.year_added = pd.DatetimeIndex(data_movies.date_added).year
# <ipython-input-37-5239cfe103ab>:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   data_shows.year_added = pd.DatetimeIndex(data_shows.date_added).year

# %%
# Top Actors- TV Shows on Netflix
cast_shows = data_shows[data_shows.cast != 'No Cast'].set_index('title').cast.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(15,7))
plt.title('Top 10 Actors of TV Shows on Netflix')
sns.countplot(y = cast_shows, order = cast_shows.value_counts().index[:10])
plt.show()

# %% [markdown]
# ## 3.7 Top 10 Actors of Movies on Netflix

# %%
# Top Actors- Movies on Netflix
cast_movies = data_movies[data_movies.cast != 'No Cast'].set_index('title').cast.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(15,7))
plt.title('Top 10 Actors of Movies on Netflix')
sns.countplot(y = cast_movies, order = cast_movies.value_counts().index[:10])
plt.show()

# %% [markdown]
# ## 3.8 Top 20 Directors on Netflix

# %%
directors = data.set_index('title').director.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
directors = directors[directors != 'No Director']
plt.figure(figsize=(15,7))
plt.title('Top 20 Directors on Netflix')
top20_di = directors.value_counts().index[:20]
sns.countplot(y = directors, order = top20_di)
plt.show()

# %% [markdown]
# ## 3.9 Top 20 Genres on Netflix

# %%
genres = data[data.genres != 'No Genre'].set_index('title').genres.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
plt.figure(figsize=(15,7))
sns.countplot(y = genres, order = genres.value_counts().index[:20])
plt.title('Top 20 Genres on Netflix')
plt.xlabel('Titles')
plt.ylabel('Genres')
plt.show()

# %% [markdown]
# ## 3.10 Top 5 Productive Countries for the Type of the Show(TV Show/Movie)

# %%
top_productive_countries=data[(data['country']=='United States')|(data['country']=='India')|(data['country']=='United Kingdom')|(data['country']=='Japan')|
                             (data['country']=='South Korea')]
plt.figure(figsize=(15,7))
sns.countplot(x='country',hue='type',data=top_productive_countries)
plt.title('Representation of Top 5 Countries for the types of shows on Netflix ')
plt.show()

# %% [markdown]
# ## 3.11 Grouping of types for duration on Netflix

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='type',hue='duration',data=data.head(20))
plt.title('Grouping of types for duration on Netflix')
plt.show()

# %% [markdown]
# ## 3.12 Total content added across all years up to 2021

# %%
# Amount of Content as a Function of Time
data_year = data.year_added.value_counts().to_frame().reset_index().rename(columns={"index": "year", "year_added":"count"})
data_year = data_year[data_year.year != 2019]

movies_year = data_movies.year_added.value_counts().to_frame().reset_index().rename(columns={"index": "year", "year_added":"count"})
movies_year = movies_year[movies_year != 2019]

shows_year= data_shows.year_added.value_counts().to_frame().reset_index().rename(columns={"index": "year", "year_added":"count"})
shows_year= shows_year[shows_year != 2019]

# %%
fig, ax = plt.subplots(figsize=(15, 7))
sns.lineplot(data=data_year, x='year', y='date_added')
sns.lineplot(data=movies_year, x='year', y='date_added')
sns.lineplot(data=shows_year, x='year', y='date_added')
ax.set_xticks(np.arange(2008, 2022, 1))
plt.title("Total content added across all years up to 2021")
plt.legend(['Total','Movie','TV Show'])
plt.ylabel("Releases")
plt.xlabel("Year")
plt.show()

# %% [markdown]
# ## 3.13 Amount of Content by Rating- Movies vs TV Shows

# %%
order = data.rating.unique()
count_movies = data_movies.groupby('rating')['title'].count().reset_index()
count_shows =data_shows.groupby('rating')['title'].count().reset_index()
count_shows.sort_values(by="rating", ascending=True)
plt.figure(figsize=(15,7))
plt.title('Amount of Content by Rating- Movies vs TV Shows')
plt.bar(count_movies.rating, count_movies.title)
plt.bar(count_shows.rating, count_shows.title, bottom=count_shows.title)
plt.legend(['TV Shows', 'Movies'])
plt.show()

# %% [markdown]
# ## 3.14 Boxplot for Duration of Content

# %%
sns.set_theme(style="whitegrid")
sns.boxplot(y = data.duration)
plt.title('Boxplot for Duration')
plt.show()

# %% [markdown]
# ## Insights:
#
# - The content type which is more on Netflix is "Movies".
# - The country which has more number of releases is "United States".
# - The most popular director on Netflix is "Jan Suter".
# - The most popular genre on Netflix is "International Movies".
# - Most of the Netflix content is made with a "TV-14" rating.
# - Netflix started gaining traction after 2014. Since then, the amount of content added has been increasing significantly.
# - The most popular actor on Netflix TV Shows is "Takahiro Sakurai".
# - The most popular actor on Netflix movie is "Anupam Kher".
# - The year '2018' has more number of releases on Netflix.
# - Duration of the shows were mostly in between 10 to 110.
